# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv(r"C:\data sets\uber-rides-dataset.csv")
dataset
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
dataset.head()
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
dataset.shape
# Out:
# (6433, 14)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   object
#  1   dropoff          6433 non-null   object
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 703.7+ KB

# %%
dataset.describe()
# Out:
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# std       1.203768     3.827867    11.551804     2.44856     1.415267
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# 50%       1.000000     1.640000     9.500000     1.70000     0.000000
# 75%       2.000000     3.210000    15.000000     2.80000     0.000000
# max       6.000000    36.700000   150.000000    33.20000    24.020000
#
#              total
# count  6433.000000
# mean     18.517794
# std      13.815570
# min       1.300000
# 25%      10.800000
# 50%      14.160000
# 75%      20.300000
# max     174.820000

# %%
dataset.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
dataset["payment"].fillna(dataset["payment"].mode()[0], inplace=True)
dataset["pickup_zone"].fillna(dataset["pickup_zone"].mode()[0], inplace=True)
dataset["dropoff_zone"].fillna(dataset["dropoff_zone"].mode()[0], inplace=True)
dataset["pickup_borough"].fillna(dataset["pickup_zone"].mode()[0], inplace=True)
dataset["dropoff_borough"].fillna(dataset["dropoff_borough"].mode()[0], inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12628\444504553.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["payment"].fillna(dataset["payment"].mode()[0], inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12628\444504553.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset.isnull().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %% [markdown]
# #It shows pickup_day, pickup_hour, pickup_month, pickup_year

# %%
dataset["pickup"] = pd.to_datetime(dataset["pickup"])
dataset["pickup_day"] = dataset["pickup"].dt.day_name()  # Monday, Tuesday, etc.
dataset["pickup_hour"] = dataset["pickup"].dt.hour  # 0-23
dataset["pickup_month"] = dataset["pickup"].dt.month  # 1-12
dataset["pickup_year"] = dataset["pickup"].dt.year

# %%
dataset
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
dataset[["pickup", "pickup_day", "pickup_hour", "pickup_month" ,"pickup_year"]].head()
# Out:
#                pickup pickup_day  pickup_hour  pickup_month  pickup_year
# 0 2019-03-23 20:21:09   Saturday           20             3         2019
# 1 2019-03-04 16:11:55     Monday           16             3         2019
# 2 2019-03-27 17:53:01  Wednesday           17             3         2019
# 3 2019-03-10 01:23:59     Sunday            1             3         2019
# 4 2019-03-30 13:27:42   Saturday           13             3         2019

# %%
# Ensure the pickup and dropoff columns are in datetime format
dataset['pickup'] = pd.to_datetime(dataset['pickup'], errors='coerce')
dataset['dropoff'] = pd.to_datetime(dataset['dropoff'], errors='coerce')

# Create the trip_duration column in minutes
dataset['trip_duration'] = (dataset['dropoff'] - dataset['pickup']).dt.total_seconds() / 60.0

# Verify the new column
print(dataset[['pickup', 'dropoff', 'trip_duration']].head())
# Out:
#                pickup             dropoff  trip_duration
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24       6.250000
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00       7.083333
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25       7.400000
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51      25.866667
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14       9.533333

# %% [markdown]
# #Fill missing values again

# %%
dataset['payment'].fillna('Unknown', inplace=True)
dataset['pickup_zone'].fillna('Unknown', inplace=True)
dataset['dropoff_zone'].fillna('Unknown', inplace=True)
dataset['pickup_borough'].fillna('Unknown', inplace=True)
dataset['dropoff_borough'].fillna('Unknown', inplace=True)
print(dataset.isnull().sum())
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# pickup_day         0
# pickup_hour        0
# pickup_month       0
# pickup_year        0
# dtype: int64
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10352\539064224.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# Summary statistics
summary_stats = dataset.describe()

# Check for outliers using IQR method
q1 = dataset['fare'].quantile(0.25)
q3 = dataset['fare'].quantile(0.75)
iqr = q3 - q1
outliers = dataset[(dataset['fare'] < (q1 - 1.5 * iqr)) | (dataset['fare'] > (q3 + 1.5 * iqr))]
outliers
# Out:
#                   pickup              dropoff  passengers  distance  fare  \
# 22   2019-03-28 17:20:54  2019-03-28 17:55:57           1      9.82  31.5
# 42   2019-03-30 23:59:14  2019-03-30 23:59:17           1      0.00  80.0
# 43   2019-03-27 19:39:16  2019-03-27 20:00:26           1      9.50  28.0
# 44   2019-03-14 07:19:29  2019-03-14 07:45:51           1      9.37  29.5
# 53   2019-03-20 18:49:24  2019-03-20 19:12:40           1     13.45  36.0
# ...                  ...                  ...         ...       ...   ...
# 6398 2019-03-17 13:07:29  2019-03-17 13:51:56           1     18.39  50.5
# 6400 2019-03-22 17:41:23  2019-03-22 18:26:00           1     13.77  43.5
# 6417 2019-03-10 12:10:45  2019-03-10 12:43:05           2     11.17  35.0
# 6421 2019-03-24 09:07:15  2019-03-24 09:36:45           6     10.23  33.0
# 6429 2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
#
#         tip  tolls   total   color      payment             pickup_zone  \
# ...

# %% [markdown]
# #Peak Hours for Uber Rides

# %%
rides_by_hour = dataset['pickup_hour'].value_counts().sort_index()
plt.figure()
sns.barplot(x=rides_by_hour.index, y=rides_by_hour.values, palette='viridis')
plt.title('Uber Rides by Pickup Hour')
plt.xlabel('Pickup Hour')
plt.ylabel('Number of Rides')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10352\1893068975.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rides_by_hour.index, y=rides_by_hour.values, palette='viridis')

# %% [markdown]
# #Ride Demand Variation Across Boroughs (using pickup_borough)

# %%
rides_by_borough = dataset['pickup_borough'].value_counts()
plt.figure()
sns.barplot(x=rides_by_borough.index, y=rides_by_borough.values, palette='plasma')
plt.title('Ride Demand by Pickup Borough')
plt.xlabel('Pickup Borough')
plt.ylabel('Number of Rides')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10352\412424016.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rides_by_borough.index, y=rides_by_borough.values, palette='plasma')

# %% [markdown]
# #Average Trip Duration by Pickup Zone

# %%
avg_duration_by_zone = dataset.groupby('pickup_zone')['trip_duration'].mean().sort_values(ascending=False)
print("Average Trip Duration by Pickup Zone (in minutes):")
print(avg_duration_by_zone)
plt.figure()
avg_duration_by_zone.plot(kind='bar', color='teal')
plt.title('Average Trip Duration by Pickup Zone')
plt.xlabel('Pickup Zone')
plt.ylabel('Average Trip Duration (minutes)')
plt.xticks(rotation=45)
plt.show()
# Out:
# Average Trip Duration by Pickup Zone (in minutes):
# pickup_zone
# Middle Village               57.933333
# Springfield Gardens North    54.616667
# Howard Beach                 52.366667
# East Flushing                50.958333
# Brighton Beach               50.583333
#                                ...
# Glendale                      5.733333
# Murray Hill-Queens            0.516667
# Hunts Point                   0.316667
# Bayside                       0.216667
# Dyker Heights                 0.066667
# Name: trip_duration, Length: 195, dtype: float64

# %% [markdown]
# #correlation between fare, distance, trip duration, and tolls

# %%
corr_matrix = dataset[['fare', 'distance', 'trip_duration', 'tolls']].corr()
print("Correlation Matrix:")
print(corr_matrix)
plt.figure()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation between Fare, Distance, Trip Duration, and Tolls')
plt.show()
# Out:
# Correlation Matrix:
#                    fare  distance  trip_duration     tolls
# fare           1.000000  0.920108       0.848068  0.609307
# distance       0.920108  1.000000       0.821321  0.635267
# trip_duration  0.848068  0.821321       1.000000  0.459609
# tolls          0.609307  0.635267       0.459609  1.000000

# %% [markdown]
# #Tip Percentage

# %%
dataset['tip_percentage'] = np.where(dataset['fare'] > 0, dataset['tip'] / dataset['fare'] * 100, 0)
plt.figure()
sns.histplot(dataset['tip_percentage'], bins=30, kde=True, color='purple')
plt.title('Tip Percentage Distribution')
plt.xlabel('Tip Percentage (%)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #Impact of Tolls on Total Fare

# %%
plt.figure()
sns.scatterplot(x='tolls', y='total', data=dataset, alpha=0.6, color='green')
plt.title('Impact of Tolls on Total Fare')
plt.xlabel('Tolls ($)')
plt.ylabel('Total Fare ($)')
plt.show()

# %% [markdown]
# #Most Commonly Used Payment Method

# %%
payment_counts = dataset['payment'].value_counts()
print("Payment Method Distribution:")
print(payment_counts)
plt.figure()
sns.barplot(x=payment_counts.index, y=payment_counts.values, palette='pastel')
plt.title('Payment Method Distribution')
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.show()
# Out:
# Payment Method Distribution:
# payment
# credit card    4577
# cash           1812
# Unknown          44
# Name: count, dtype: int64
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10352\1913466217.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=payment_counts.index, y=payment_counts.values, palette='pastel')

# %% [markdown]
#  #Impact of Number of Passengers on Fare

# %%
plt.figure()
sns.boxplot(x='passengers', y='fare', data=dataset, palette='magma')
plt.title('Fare Distribution by Number of Passengers')
plt.xlabel('Number of Passengers')
plt.ylabel('Fare ($)')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10352\2845212012.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='passengers', y='fare', data=dataset, palette='magma')

# %% [markdown]
# #Top 10 Pickup Zones

# %%
top_pickup_zones = dataset['pickup_zone'].value_counts().head(10)
plt.figure()
sns.barplot(x=top_pickup_zones.index, y=top_pickup_zones.values, palette='Blues_d')
plt.title('Top 10 Pickup Zones')
plt.xlabel('Pickup Zone')
plt.ylabel('Number of Rides')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10352\1473036323.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_pickup_zones.index, y=top_pickup_zones.values, palette='Blues_d')

# %% [markdown]
# #Top 10 Dropoff Zones

# %%
top_dropoff_zones = dataset['dropoff_zone'].value_counts().head(10)
plt.figure()
sns.barplot(x=top_dropoff_zones.index, y=top_dropoff_zones.values, palette='Greens_d')
plt.title('Top 10 Drop-off Zones')
plt.xlabel('Drop-off Zone')
plt.ylabel('Number of Rides')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10352\3661722247.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_dropoff_zones.index, y=top_dropoff_zones.values, palette='Greens_d')

# %% [markdown]
# #Comparing Ride Demand by Borough

# %%
pickup_borough_counts = dataset['pickup_borough'].value_counts()
dropoff_borough_counts = dataset['dropoff_borough'].value_counts()

fig, ax = plt.subplots(1, 2, figsize=(14, 6))
sns.barplot(x=pickup_borough_counts.index, y=pickup_borough_counts.values, ax=ax[0], palette='coolwarm')
ax[0].set_title('Pickup Borough Ride Demand')
ax[0].set_xlabel('Borough')
ax[0].set_ylabel('Number of Rides')
ax[0].tick_params(axis='x', rotation=45)

sns.barplot(x=dropoff_borough_counts.index, y=dropoff_borough_counts.values, ax=ax[1], palette='coolwarm')
ax[1].set_title('Drop-off Borough Ride Demand')
ax[1].set_xlabel('Borough')
ax[1].set_ylabel('Number of Rides')
ax[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10352\3268044598.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pickup_borough_counts.index, y=pickup_borough_counts.values, ax=ax[0], palette='coolwarm')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10352\3268044598.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=dropoff_borough_counts.index, y=dropoff_borough_counts.values, ax=ax[1], palette='coolwarm')
